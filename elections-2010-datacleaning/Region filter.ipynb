# %%
import pandas as pd
from pandas import DataFrame

df = pd.read_csv("all-2010-clean.csv")

# %%
datar = df[df.region.str.contains('Донецька|Луганська|Харківська|Дніпропетровська|Кіровоградська|Запоріжська|Миколаївська|Херсонська|Одеська|').fillna(False)]

# %%
print regionfilter
# Out:
#                                                   party  \
# 0                                      Партія регіонів
# 1                                      Партія регіонів
# 2                          Комуністична партія України
# 3                    Політична партія "Сильна Україна"
# 4                          Комуністична партія України
# 5                Політична партія Народний Рух України
# 6                                        Партія "Союз"
# 7                                      Партія регіонів
# 8                                      Партія регіонів
# 9                                      Партія регіонів
# 10                                     Партія регіонів
# 11               Політична партія Народний Рух України
# 12                                       Партія "Союз"
# 13                         Комуністична партія України
# 14                   Політична партія "Сильна Україна"
# 15                         Комуністична партія України
# ...

# %%
regionfilter = datar.to_csv("filteredregions-2010.csv")

# %%
filteredregions = pd.read_csv("filteredregions-2010.csv")
name = df.party.unique()
array = [name]
filteredregions = pd.DataFrame({'Names':array})
filteredregions.to_csv('names-filtered-2010', encoding='utf-8')
uni = pd.read_csv('names-filtered-2010', index_col = [0], encoding='utf-8')
print uni
